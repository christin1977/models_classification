# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
#referentiel base source
source_portfolio=pd.read_csv('base_portefeuille.csv', encoding='utf-8', sep=',', on_bad_lines='skip')
source_portfolio.shape
# Out:
# (126, 365)

# %%
source_portfolio = source_portfolio[source_portfolio['siren']==312 480 205]
source_portfolio
# Out:
#   Cell In[34], line 1
#     source_portfolio = source_portfolio[source_portfolio['siren']==312 480 205]
#                                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Définir les années pour lesquelles les données sont générées
annees=['2018','2019','2020','2021','2022']
donnees = [
    [source_portfolio.loc[:, 'robustness_ratio_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'solvability_ratio_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'reimbursement_ratio_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'revenue_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'resultat_d_exploitation_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'net_result_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'FRN_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'RdtCpx_' + str(year)].dropna().tolist() for year in annees],
    [source_portfolio.loc[:, 'RCI_' + str(year)].dropna().tolist() for year in annees],
]


# Définir les années pour lesquelles les données sont générées
annees = np.arange(2018, 2023)
largeur_barre = 0.35  # Largeur des barres pour le graphique

# Noms des variables / data pour chaque subplot (9 pour une grille 3x3)
noms_variables = ['robustesse', 'solvabilité', 'endettement', 'chiffres d affaires', 'ROE', 'resultat net', 'FRN', 'Rdt des capitaux', 'RCI']

# Structure des données (exemple basé sur des données simulées)
donnees = [
    [np.random.rand() * 100 for year in annees] for _ in range(9)
]

# Créer une figure et une grille de subplots 3x3
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15), sharex=True, sharey=False)

# Titre général pour la figure
fig.suptitle('Analyse par variable et année', fontsize=16)

for i, ax_row in enumerate(axes):
    for j, ax in enumerate(ax_row):
        idx = i * 3 + j  # Index pour accéder aux noms_variables et données
        data_to_plot = donnees[idx]  # Sélection des données pour la variable courante
        
        # Ajustement en fonction du type de graphique
        if i == 0:  # Première ligne: graphiques à barres
            ax.bar(annees, data_to_plot, color='skyblue', edgecolor='black')
        elif i == 1:  # Deuxième ligne: graphiques linéaires
            ax.plot(annees, data_to_plot, marker='o', linestyle='-', color='green')
        elif i == 2:  # Troisième ligne: diagrammes de dispersion
            ax.bar(annees, data_to_plot, color='red', edgecolor='black')
        
        ax.set_title(noms_variables[idx])
        ax.set_xticks(annees)
        ax.set_xticklabels(annees, rotation=45)

# Ajustement de l'espacement
plt.tight_layout()
plt.subplots_adjust(top=0.92)

# Afficher la figure
plt.show()

# %%
data = {
    'Variable': ['Robustesse', 'Solvabilité', 'Endettement', 'Chiffre d\'affaire', 'Résultat d\'exploitation', 'Résultat net', 'FRN', 'RdtCpx', 'RCI'],
    '2018': [source_portfolio['robustness_ratio_2018'].tolist(), source_portfolio['solvability_ratio_2018'].tolist(),source_portfolio['reimbursement_ratio_2018'].tolist(),source_portfolio['revenue_2018'].tolist(),source_portfolio['resultat_d_exploitation_2018'].tolist(),source_portfolio_cie_immo['net_result_2018'].tolist(),source_portfolio['FRN_2018'].tolist(),source_portfolio['RdtCpx_2018'].tolist(),source_portfolio['RCI_2018'].tolist()],
    '2019': [source_portfolio['robustness_ratio_2019'].tolist(), source_portfolio['solvability_ratio_2019'].tolist(),source_portfolio['reimbursement_ratio_2019'].tolist(),source_portfolio['revenue_2019'].tolist(),source_portfolio['resultat_d_exploitation_2019'].tolist(),source_portfolio_cie_immo['net_result_2019'].tolist(),source_portfolio['FRN_2019'].tolist(),source_portfolio['RdtCpx_2019'].tolist(),source_portfolio['RCI_2019'].tolist()],
    '2020': [source_portfolio['robustness_ratio_2020'].tolist(), source_portfolio['solvability_ratio_2020'].tolist(),source_portfolio['reimbursement_ratio_2020'].tolist(),source_portfolio['revenue_2020'].tolist(),source_portfolio['resultat_d_exploitation_2020'].tolist(),source_portfolio_cie_immo['net_result_2020'].tolist(),source_portfolio['FRN_2020'].tolist(),source_portfolio['RdtCpx_2020'].tolist(),source_portfolio['RCI_2020'].tolist()],
    '2021': [source_portfolio['robustness_ratio_2021'].tolist(), source_portfolio['solvability_ratio_2021'].tolist(),source_portfolio['reimbursement_ratio_2021'].tolist(),source_portfolio['revenue_2021'].tolist(),source_portfolio['resultat_d_exploitation_2021'].tolist(),source_portfolio_cie_immo['net_result_2021'].tolist(),source_portfolio['FRN_2021'].tolist(),source_portfolio['RdtCpx_2021'].tolist(),source_portfolio['RCI_2021'].tolist()],
    '2022': [source_portfolio['robustness_ratio_2022'].tolist(), source_portfolio['solvability_ratio_2022'].tolist(),source_portfolio['reimbursement_ratio_2022'].tolist(),source_portfolio['revenue_2022'].tolist(),source_portfolio['resultat_d_exploitation_2022'].tolist(),source_portfolio_cie_immo['net_result_2022'].tolist(),source_portfolio['FRN_2022'].tolist(),source_portfolio['RdtCpx_2022'].tolist(),source_portfolio['RCI_2022'].tolist()]

}

# Créer un DataFrame pour résumer les données
summary_df = pd.DataFrame(data)

# Afficher le DataFrame résumé
print(summary_df)
# Out:
#                   Variable                                               2018  \
# 0               Robustesse  [0.0038962247011502, 0.0006871815364554, 0.0, ...
# 1              Solvabilité  [5.279357608874217, 5.164358865387054, -0.0, 0...
# 2              Endettement  [1.0, 1.0915254485194088, -inf, 1.412517086506...
# 3        Chiffre d'affaire  [56170785.0, 148345080.0, 73395138.0, 22929000...
# 4  Résultat d'exploitation  [282974.0, 229981.0, 967295.0, 4189000.0, 2628...
# 5             Résultat net                                                 []
# 6                      FRN  [8752553.0, 31698829.0, 25500.0, -43401.0, 671...
# 7                   RdtCpx  [0.1070035828554888, 0.0146178473964988, nan, ...
# 8                      RCI  [0.0250045900893145, 0.0032158916659034, 0.0, ...
#
#                                                 2019  \
# 0  [0.0082320591599223, 0.0006225682127249, 0.0, ...
# 1  [4.656993060212998, 5.247863706984358, nan, 2....
# ...

# %%
for col in summary_df.columns:
    if col != 'Variable':  # Ignorer la colonne 'Variable'
        summary_df[col] = summary_df[col].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else (np.nan if isinstance(x, list) else x))

# Appliquer une mise en forme conditionnelle
styled_df = summary_df.style.applymap(lambda x: 'color: red' if isinstance(x, str) and 'Résultat' in x else 'color: black').format("{:,.2f}", na_rep="N/A", subset=pd.IndexSlice[:, '2018':'2022']).background_gradient(cmap='viridis', subset=pd.IndexSlice[:, '2018':'2022'])

# Afficher le DataFrame stylisé
styled_df
# Out:
# C:\Users\chris\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3618: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\chris\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3619: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_b92af_row0_col0, #T_b92af_row1_col0, #T_b92af_row2_col0, #T_b92af_row3_col0, #T_b92af_row6_col0, #T_b92af_row7_col0, #T_b92af_row8_col0 {
#   color: black;
# }
# #T_b92af_row0_col1, #T_b92af_row0_col2, #T_b92af_row0_col3, #T_b92af_row0_col4, #T_b92af_row1_col1, #T_b92af_row1_col2, #T_b92af_row1_col3, #T_b92af_row1_col4, #T_b92af_row2_col1, #T_b92af_row2_col2, #T_b92af_row2_col3, #T_b92af_row2_col4, #T_b92af_row4_col3, #T_b92af_row7_col1, #T_b92af_row7_col2, #T_b92af_row7_col3, #T_b92af_row7_col4, #T_b92af_row8_col1, #T_b92af_row8_col2, #T_b92af_row8_col3, #T_b92af_row8_col4 {
#   color: black;
# ...
